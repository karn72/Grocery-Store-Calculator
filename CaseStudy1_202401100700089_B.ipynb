# %% [markdown]
# <a href="https://colab.research.google.com/github/karn72/Grocery-Store-Calculator/blob/main/CaseStudy1_202401100700089_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Grocery store calculator
print("Welcome to the grocery store calculator")
print("Avialable Items : ")
print("Flour")
print("Rice")
print("Spices")
print("Pulses")
print("Bread")
print("Milk")
print("Cheese")
print("Yogurt")
print("Oil")
print("Biscuits")
print("Snacks and Namkeens")
print("Sugar")
print("Tea")
print("Coffee")
print("Water")
print("Cold Drinks")
print("Beauty Items")
print("Stationery")
print("Toys")
print("Toiletries")

item = input("Enter the item you want to buy: ")
if(item=="Flour"):
  print("Price is : 20")
  qty=int(input("Enter the quantity: "))
  print("Total price is : ",qty*20)
  print("Thankyou")
elif(item=="Rice"):
  print("Price is : 45")
  qty=int(input("Enter the quantity: "))
  print("Total price is : ",qty*45)
  print("Thankyou")
elif(item=="Spices"):
  print("Price is : 50")
  qty=int(input("Enter the quantity: "))
  print("Total price is : ",qty*50)
  print("Thankyou")
elif(item=="Pulses"):
    print("Price is : 120")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*120)
    print("Thankyou")
elif(item=="Bread"):
    print("Price is : 40")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*40)
    print("Thankyou")
elif(item=="Milk"):
    print("Price is : 50")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*50)
    print("Thankyou")
elif(item=="Cheese"):
    print("Price is : 100")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*100)
    print("Thankyou")
elif(item=="Yogurt"):
    print("Price is : 40")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*40)
    print("Thankyou")
elif(item=="Oil"):
    print("Price is : 150")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*150)
    print("Thankyou")
elif(item=="Biscuits"):
    print("Price is : 30")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*30)
    print("Thankyou")
elif(item=="Snacks and Namkeens"):
    print("Price is : 20")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*20)
    print("Thankyou")
elif(item=="Sugar"):
    print("Price is : 40")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*40)
    print("Thankyou")
elif(item=="Tea"):
    print("Price is : 50")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*50)
    print("Thankyou")
elif(item=="Coffee"):
    print("Price is : 100")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*100)
    print("Thankyou")
elif(item=="Water"):
    print("Price is : 10")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*10)
    print("Thankyou")
elif(item=="Cold Drinks"):
    print("Price is : 30")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*30)
    print("Thankyou")
elif(item=="Beauty Items"):
    print("Price is : 100")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*100)
    print("Thankyou")
elif(item=="Stationery"):
    print("Price is : 20")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*20)
    print("Thankyou")
elif(item=="Toys"):
    print("Price is : 50")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*50)
    print("Thankyou")
elif(item=="Toiletries"):
    print("Price is : 50")
    qty=int(input("Enter the quantity: "))
    print("Total price is : ",qty*50)
    print("Thankyou")
else:
  print("Sorry! This item not avialable")
  print("Thankyou")
# Out:
# Welcome to the grocery store calculator
# Avialable Items :
# Flour
# Rice
# Spices
# Pulses
# Bread
# Milk
# Cheese
# Yogurt
# Oil
# Biscuits
# Snacks and Namkeens
# Sugar
# Tea
# Coffee
# Water
# Cold Drinks
# Beauty Items
# Stationery
# Toys
# Toiletries
# Enter the item you want to buy: Spices
# Price is : 50
# Enter the quantity: 6
# Total price is :  300
# Thankyou
